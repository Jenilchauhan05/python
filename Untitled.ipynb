# %% [markdown]
# Extra Python Programms - Files IO

# %%
f = open("data.txt", "r")
print(f.read())
f.close()
# Out:
# hello, my name is Jenil Chauhan.
# I am studying Computer science in Btech.
# I studying in Darshan University.

# %%
f = open("data.txt", "r")
print(f.readline())
print(f.readline())
print(f.readline())
f.close()
# Out:
# hello, my name is Jenil Chauhan.
#
# I am studying Computer science in Btech.
#
# I studying in Darshan University.

# %%
f = open("data.txt", "w")

f.write("text to overwrite \n the complete data.")
f.close()

# %%
f = open("data.txt", "a")

f.write("new text being appended to the file.")
f.close()

# %%
f = open("data1.txt", "w")

f.write("new file created in \n this file using x \n and if exist then error occurs")
f.close()

# %% [markdown]
# seek(offset, from_where)
# from_where :
#     0 from beginning of the file
#     1 from current position of the file pointer
#     2 from end of the line

# %%
import os

os.remove("data2.txt")

# %%
f = open("new1.txt", "x")

f.write("new text being appended to the file.")
f.close()

# %%
with open("data.txt", "r") as f :
    data = f.read()
    print(f"{data}, {len(data)}")
# Out:
# text to overwrite
#  the complete data.
# new text being appended
#  to the file.
# new text being appended
#  to the file.new text being appended
#  to the file.new text being appended to the file., 190
