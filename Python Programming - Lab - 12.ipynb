# %% [markdown]
# <a href='https://www.darshan.ac.in/'> <img src='https://www.darshan.ac.in/Content/media/DU_Logo.svg' width="250" height="300"/></a>
# <pre>
# <center><b><h1>Python Programming - 2301CS404</b></center>
# <center><b><h1>Lab - 12</b></center>
# <center><b><h3>Roll No : 325</b></center>
# <center><b><h3>Name : Chauhan Jenil V.</b></center>
# <pre>

# %% [markdown]
# # Exception Handling

# %% [markdown]
# ### 01) WAP to handle following exceptions:
# 1. ZeroDivisionError
# 2. ValueError
# 3. TypeError
# #### Note: handle them using separate except blocks and also using single except block too.

# %%
try :
    a = int(input("enter the a"))
    b = int(input("enter the b"))
    res = a // b
    
    print(res)
    print(str(a) + b)
    
except ZeroDivisionError :
    print("cant divide by 0")
except ValueError :
    print("give valid integers")
except TypeError :
    print("type error")
# Out:
# enter the a 5
# enter the b d
# give valid integers

# %% [markdown]
# ### 02)  WAP to handle following exceptions:
# 1. IndexError
# 2. KeyError

# %%
try :
    l1 = [10, 20, 30, 40, 50]
    idx = int(input("enter the index"))
    print(l1[idx])

    d1 = {"name" : "Jenil"}
    print(d1["age"])
    
except IndexError :
    print("index out of bound")
except KeyError :
    print("key not found in dictionary")
# Out:
# enter the index 3
# 40
# key not found in dictionary

# %% [markdown]
# ### 03) WAP to handle following exceptions:
# 1. FileNotFoundError
# 2. ModuleNotFoundError

# %%
try :
    f = open("data.txt", "r")
    print(f.read())
    f.close()

    import unknown
    
except FileNotFoundError :
    print("file is not found")
except ModuleNotFoundError :
    print("module not found")
# Out:
# text to overwrite
#  the complete data.
# new text being appended
#  to the file.
# new text being appended
#  to the file.new text being appended
#  to the file.new text being appended to the file.
# module not found

# %% [markdown]
# ### 04) WAP that handles all type of exceptions in a single except block in standard error message format.

# %%
try :
    a = int(input("enter the a"))
    b = int(input("enter the b"))
    
    res = a // b
    print(res)

except Exception as e :
    print(e)
# Out:
# enter the a 4
# enter the b 0
# integer division or modulo by zero

# %% [markdown]
# ### 05) WAP to demonstrate else  and finally block.

# %%
try :
    a = int(input("enter the a"))
    b = int(input("enter the b"))
    
    res = a // b
    print(res)

except Exception as e :
    print(e)
else :
    print("else is executed")
finally :
    print("finally is executed")
# Out:
# enter the a 6
# enter the b 2
# 3
# else is executed
# finally is executed

# %% [markdown]
# ### 06) WAP to create an udf divide(a,b) that handles ZeroDivisionError.

# %%
def divide(a, b) :
    try :
        res = a // b
        print(res)
    except Exception as e :
        print(e)

divide(7, 0)
divide(8, 2)
# Out:
# integer division or modulo by zero
# 4

# %% [markdown]
# ### 07) WAP to accept item prices and calculate total. Raise ValueError if price is negative, otherwise print the total bill amount.

# %%
try :
    itms = [int(input("enter the price")) for i in range(3)]
    bill = 0

    for i in itms :
        if i < 0 :
            raise ValueError("negative number not allowed")
    print("total bill : ", sum(itms))

except ValueError as e :
    print(e)
# Out:
# enter the price 4
# enter the price 6
# enter the price -3
# negative number not allowed

# %% [markdown]
# ### 08) Create a short program that prompts the user for a list of grades separated by commas.
# #### Split the string into individual grades and use a list comprehension to convert each string to an integer.
# #### You should use a try statement to inform the user when the values they entered cannot be converted.

# %%
grades = input("enter the grades").split(",")

print(grades)

try :
    [int(i) for i in grades]
except Exception as e :
    print(e)
# Out:
# enter the grades 5,3,a
# ['5', '3', 'a']
# invalid literal for int() with base 10: 'a'

# %% [markdown]
# ### 09) Accept 5 subject marks (0-100). Use assert for validation.
#
# #### Sample Input (Error Case)
# #####  Enter marks: 110
#
# #### Sample Output (Error Case)
# ##### AssertionError: Marks should be between 0 and 100.
#
# #### Sample Input (Normal Case)
# ##### Valid marks entered
#
# #### Sample Output (Normal Case)
# ##### Average Marks displayed

# %%
try :
    grades = input("enter the grades")
    l1 = [int(x) for x in grades.split(",")]

    try :
        for i in l1 :
            assert i>=0 and i<=100, "invalid marks"

        print("avg = ", sum(l1) // len(l1))

    except Exception as e :
        print(e)
except Exception as e :
        print(e)
# Out:
# enter the grades 65, -1
# invalid marks

# %% [markdown]
# ### 10) WAP that gets password from user. Password must have at least 8 characters and one digit.
# ### Raise WeakPasswordError if invalid, print the messsage "Correct" otherwise.

# %%
class WeakPassword(Exception) :
    pass

try :
    password = input("enter the password")

    if len(password) < 8 or not any(char.isdigit() for char in password) :
        raise WeakPassword("weak password")
    print("valid password")

except Exception as e :
    print(e)
# Out:
# enter the password jenilcha5
# valid password

# %% [markdown]
# ### 11) WAP to raise your custom Exception named NegativeNumberError with the error message : "Cannot calculate the square root of a negative number" :
# #### if the given number is negative.
# #### otherwise print the square root of the given number.

# %%
class NegativeNumberError(Exception) :
    pass

try :
    n = int(input("enter the number"))
    if n < 0 :
        raise NegativeNumberError("cant calculate the square root of negative number")
        
except Exception as e :
    print(e)
else :
    print(n ** 0.5)
# Out:
# enter the number -4
# cant calculate the square root of negative number
