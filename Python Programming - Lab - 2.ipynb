# %% [markdown]
# <pre>
# <center><b><h1>Python Programming - 2301CS404</b></center>
# <center><b><h1>Lab - 2</b></center>
#     <b>Chauhan Jenil Virenbhai</b>
#     <b>24010101039</b>
# <pre>

# %% [markdown]
# ### 01) WAP to print “Hello World..!!”

# %%
print("hello word")
# Out:
# hello word

# %% [markdown]
# ### 02) WAP to accept your name and display a welcome message.
# #### Input: Priya
# #### Output: Hello Priya, welcome to Python Lab.

# %%
name = input("enter your name :  ")
print("hello", name, " welcome to python lab")
# Out:
# enter your name :   jenil
# hello jenil  welcome to python lab

# %% [markdown]
# ### 03) WAP to accept three integers and display the numbers, their sum, and average.
# #### Input: 10 20 30
# #### Output:
# ##### Numbers: 10 20 30
# ##### Sum: 60
# ##### Average: 20.0

# %%
a = int(input("enter first number : "))
b = int(input("enter second number : "))
c = int(input("enter third number : "))

sum = (a + b + c)
avg = (sum / 3)
print("sum =  ", sum, "avg =  ", avg)
# Out:
# enter first number :  10
# enter second number :  20
# enter third number :  30
# sum =   60 avg =   20.0

# %% [markdown]
# ### 04) WAP to accept name (string), age (int), and percentage (float).
# #### Input : Riya,18,92.5
# #### Output :
# ##### Name: Riya  Type: <class 'str'>
# ##### Age: 18  Type: <class 'int'>
# ##### Percentage: 92.5  Type: <class 'float'>

# %%
name = input("enter your name :  ")
age = int(input("enter your age :  "))
percentage = float(input("enter your percentage :  "))

print("name :  ", "type : ", type(name))
print("age :  ", "type : ", type(age))
print("percentage :  ", "type : ", type(percentage))
# Out:
# enter your name :   jenil
# enter your age :   20
# enter your percentage :   99.77
# name :   <class 'str'>
# age :   <class 'int'>
# percentage :   <class 'float'>

# %% [markdown]
# ### 05) WAP to print folowing message using custom separator and end.
# #### Ouutput : Python | Programming | Basics###

# %%
print("python ", "programming ", "basics ", sep="!", end="@@@")
# Out:
# python !programming !basics @@@

# %% [markdown]
# ### 06) WAP to accept a value and display its value, type, and memory id.
# #### Input : hello
# #### Output :
# ##### Value: hello
# ##### Type: <class 'str'>
# ##### ID: 140712345678912

# %%
name = input("enter your input :  ")
print("value :  ", name)
print("type :  ", type(name))
print("id :  ", id(name))
# Out:
# enter your input :   jenil
# value :   jenil
# type :   <class 'str'>
# id :   2372483377040

# %% [markdown]
# ### 07) WAP to assign a value to a variable, print id, reassign a new value, and print id again.
# #### Output :
# ##### Original ID of a: 140712345678912
# ##### New ID of a: 140712345678960

# %%
a = input("enter your input :  ")
print("original id of a :  ", id(a))
a = input("enter your input :  ")
print("new id of a :  ", id(a))
# Out:
# enter your input :   jenil
# original id of a :   2372483381168
# enter your input :   chauahn
# new id of a :   2372483380112

# %% [markdown]
# ### 08) WAP to print multiple lines using a single print().
# #### Output:
# ##### Welcome to Python
# ##### This is the second lab
# ##### Enjoy coding!

# %%
print("""welcome to python
this is the second lab
enjoy coding!""")
# Out:
# welcome to python
# this is the second lab
# enjoy coding!

# %% [markdown]
# ### 09) WAP to display following table of items with proper alignment.
# #### Output :
# | Sr No | Name        | Subject | Grade | Percentage |
# | ----: | ----------- | ------- | :---: | ---------: |
# |     1 | Nisha Patel | Math    |   A   |         92 |
# |     2 | Aarav Modi  | Science |   B+  |         85 |
# |     3 | Jiya Shah   | English |   A+  |         96 |

# %%
print(f"{'Sr No':10}  {'Name':10}  {'Subject':10}  {'Grade':10}  {'Percentage':10}")
print(f"{'1':10}  {'Nisha Patel':^10}  {'Math':10}  {'A':^10}  {'92':^10}")
print(f"{'2':10}  {'Aarav Modi':^10}  {'Science':10}  {'B+':^10}  {'85':^10}")
print(f"{'3':10}  {'Jiya Shah':^10}  {'English':10}  {'A+':^10}  {'96':^10}")
# Out:
# Sr No       Name        Subject     Grade       Percentage
# 1           Nisha Patel  Math            A           92
# 2           Aarav Modi  Science         B+          85
# 3           Jiya Shah   English         A+          96

# %% [markdown]
# ### 10) WAP to accept a float number and display with 2 decimals, 3 decimals, and width 10.
# #### Input : 37.2567
# #### Output :
# ##### 2 decimals: 37.26
# ##### 3 decimals: 37.257
# ##### Width 10:      37.26

# %%
n = float(input("enter the n :  "))
print("2 decimals : ", round(n, 2))
print("3 decimals : ", round(n, 3))
print(f"Width 10 : {n : 10.2f}")
# Out:
# enter the n :   37.2567
# 2 decimals :  37.26
# 3 decimals :  37.257
# Width 10 :      37.26

# %% [markdown]
# ### 11) WAP to accept two integers and display sum, difference, and product using f-strings.
# #### Input : 12 8
# #### Output :
# ##### Sum = 20
# ##### Difference = 4
# ##### Product = 96

# %%
a = int(input("enter first number : "))
b = int(input("enter second number : "))

print(f"sum = {a + b}")
print(f"diff = {a - b}")
print(f"mul = {a * b}")
# Out:
# enter first number :  12
# enter second number :  7
# sum = 19
# diff = 5
# mul = 84

# %% [markdown]
# ### 12) WAP to accept date in dd mm yyyy format and display in multiple formats.
# #### Input : 01 12 2025
# #### Output :
# ##### 01/12/2025
# ##### 2025-12-01

# %%
a = int(input("enter date : "))
b = int(input("enter month : "))
c = int(input("enter year : "))
print(a, b, c, sep="/")
print(a, b, c, sep="-")
# Out:
# enter date :  5
# enter month :  9
# enter year :  2006
# 5/9/2006
# 5-9-2006

# %% [markdown]
# ### 13) WAP to calculate area and perimeter of a circle.

# %%
r = int(input("enter radius : "))
print("perimeter = ", 2*3.14*r)
print("area = ", 3.14*r*r)
# Out:
# enter radius :  7
# perimeter =  43.96
# area =  153.86

# %% [markdown]
# ### 14) WAP to convert degree into Fahrenheit and vice versa.

# %%
f = int(input("enter temperature : "))
print("temperature in farenheit :", (f - 32) * 5/9)
# Out:
# enter temperature :  7
# temperature in farenheit : -13.88888888888889

# %% [markdown]
# ### 15) WAP to get the distance from user into kilometer, and convert it into meter, feet, inches and centimeter.

# %%
d = int(input("enter distance in kilometer : "))
print("distance in meter = ", d * 1000)
print("distance in feet = ", d / 0.0003048)
print("distance in inches = ", d * 39370.07874)
print("distance into cm = ", d * 1000 * 100)
# Out:
# enter distance in kilometer :  7
# distance in meter =  7000
# distance in feet =  22965.879265091866
# distance in inches =  275590.55117999995
# distance into cm =  700000
